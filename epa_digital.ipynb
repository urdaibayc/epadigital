# %%
import pandas as pd

# %%
sponsorship = pd.read_csv('epa_data_analyst_sponsorship.csv')
data = pd.read_csv('epa_data_analyst_raw.csv')

# %%
sponsorship
# Out:
#                                   sponsorship         cost
# 0                                    Paquetes     $27,900
# 1               Cintillos/Banners Principales  $1,500,000
# 2                               Diamante Fijo    $500,000
# 3                           Diamante Cintillo    $430,000
# 4                               Diamante Logo    $390,000
# 5                            Platino Cintillo    $250,000
# 6                                Platino Fijo    $235,000
# 7                                     Platino    $180,000
# 8                                Oro Cintillo    $135,000
# 9                                    Oro Fijo    $120,000
# 10                                        Oro     $85,000
# 11                                     Luxury     $62,000
# 12                             Plata Cintillo     $88,000
# 13                                 Plata Fijo     $65,000
# 14                                      Plata     $42,000
# ...

# %%
data
# Out:
#              date              section                    brand  \
# 0      2021-05-23  alimentos y bebidas                beerhouse
# 1      2021-05-23  alimentos y bebidas          bodegas alianza
# 2      2021-05-23  alimentos y bebidas                didi food
# 3      2021-05-23  alimentos y bebidas  el patron de los chiles
# 4      2021-05-23  alimentos y bebidas                 enfashop
# ...           ...                  ...                      ...
# 86404  2021-06-10               viajes                    fedex
# 86405  2021-06-10               viajes                   id4you
# 86406  2021-06-10               viajes             mercado pago
# 86407  2021-06-10               viajes   secretaria de economia
# 86408  2021-06-10               viajes                  barcelo
#
#                  Category1          sponsorship creativeType  impressions  \
# 0      alimentos y bebidas                  Oro      product          374
# ...
